# %%
#############################################################################
####################Import all packages######################################
#############################################################################
import os
import random
import numpy as np
#import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt
#import pandas_profiling as pp
import pandas as pd
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.options.mode.chained_assignment = None  # default='warn'
# Set working directory
#############################################################################
# Make Jupyter Notebook show ALL output of a cell, not only the last one
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
def read_all_csvs_in_folder(path):
    ''' Function reading in all CSV files in a given folder.
        1. First lists all files in folder.
        2. Then reads in only files which are NOT of file size = 0 and contain headers + AT LEAST 1 row of data
        3. Appends all files into a final dataframe
        4. Also prints the amount of files in the folder, and the amount of files used for the final dataframe.
    '''
    import pandas as pd
    import glob
    import os
    # Create list containing all files names of the current folder
    all_files = glob.glob(path + "/*.csv")
    # These empty lists will be filled with:
    # 1. the names of the CSV files we want to append/merge, 
    # 2. 2 lists containing numbers representing all the files that were empty (or headers but no row data) and not read
    
    list_with_dfs = []
    zero_files = []
    empty_files = []
    empty_row_files = []
    filename_list = []
    n_files_appended = 0
    
    print('')
    print('')
    print('#####################################################')
    print('STARTING READ IN')
    print('#####################################################')
    print('')
    
    for filename in all_files:        
        print('Reading current file:')
        print(filename)
        # Check whether the CSV file is larger than 0Bytes (if not, it has for sure no data and will break during read in)
        try:        
            if os.path.getsize(filename) == 0:
                zero_files.append(filename)                
                print('')
                print('------------------------------------------------------')
                print('!!! SKIPPING FILE: ' + filename)
                print('    REASON: FILE SIZE == 0')
                print('------------------------------------------------------')
                print('')
            if os.path.getsize(filename) > 0:
                df = pd.read_csv(filename, index_col=None, header=0)            
                if df.empty:
                    empty_row_files.append(filename)
                    print('')
                    print('------------------------------------------------------')
                    print('!!! SKIPPING FILE: ' + filename)
                    print('    REASON: FILE CONTAINS NO ROW DATA')
                    print('------------------------------------------------------')
                    print('')
                # Check whether the CSV is empty (this ALSO works when it DOES have headers, but no row data. This is important!)
                if not df.empty:
                    list_with_dfs.append(df)
                    n_files_appended = n_files_appended + 1
                    filename_list.append(filename)
        except pd.errors.EmptyDataError:
            print('')
            print('------------------------------------------------------')
            print('!!! SKIPPING FILE: ' + filename)
            print('    REASON: FILE ENTIRELY EMPTY WITHOUT HEADERS')
            print('------------------------------------------------------')
            print('')
            empty_files.append(filename)            
            pass
    
    # Merge all files in the file list
    frame = pd.concat(list_with_dfs, axis=0, ignore_index=True)
    print('')
    print('#####################################################')
    print('!!! DONE READING & MERGING DATA !!!')
    print('#####################################################')
    print('')
    print('------------------------------------------------------')
    print('All files: ' + str(len(all_files)))    
    print('')
    print('Successfully appended files: ' + str(n_files_appended))
    print('------------------------------------------------------')
    print('------------------------------------------------------')
    print('')
    print('Empty files without headers: ' + str(len(empty_files)))
    #print(len(empty_files))
    print(empty_files)
    print('')
    print('Zero size files: ' + str(len(zero_files)))
    #print(len(zero_files))
    print(zero_files)
    print('')
    print('Empty row files: ' + str(len(empty_row_files)))
    #print(len(empty_row_files))
    print(empty_row_files)
    print('')    
    print('#####################################################')
    
    return frame

# %%
# Read in files and merge them

#PreFlight & Flight
#path_pre_and_flight = r'../data/experiment/raw/exp_raw_pre_and_flight/' 
#pre_and_flight = read_all_csvs_in_folder(path_pre_and_flight)

path_postflight1 = '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019'
#path_postflight2 = '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata von 15032019 bis 11042019'

# PostFlight
postflight_1 = read_all_csvs_in_folder(path_postflight1)
#postflight_2 = read_all_csvs_in_folder(path_postflight2)

# Extra Flight
#path_extra = r'../data/experiment/raw/exp_raw_extra/2019-04-12(1)/2019-04-12/' 
#extra = read_all_csvs_in_folder(path_extra)
# Out:
# #####################################################
# STARTING READ IN
# #####################################################
#
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946762157.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946795043.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946876437.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data947016117.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946992497.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946828853.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946858676.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946872838.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946952177.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946807402.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946740052.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946815294.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946883756.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946931895.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946858435.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946684854.csv
#
# ------------------------------------------------------
# !!! SKIPPING FILE: /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946684854.csv
#     REASON: FILE SIZE == 0
# ------------------------------------------------------
#
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946806683.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946749679.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946886519.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946974135.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946932493.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946977619.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946759403.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946953495.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946685206.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946991300.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946997898.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946883998.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946990340.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946976420.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946798764.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946942454.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946880879.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946835455.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946814573.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946794443.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946946416.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946921814.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946811210.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946734891.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946891081.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946805484.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946860236.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946922051.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946864438.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946841394.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946894919.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946829574.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946865757.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946963699.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946757720.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946926255.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946843435.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946923373.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946866355.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946864918.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946867075.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946766483.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946929493.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946886639.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946933092.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946852674.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946859634.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946788800.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946977259.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946921455.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946811334.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946866114.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946739216.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946951815.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946962495.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946973296.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946846673.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946755920.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946779080.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946832213.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946832572.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946879079.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946950616.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946975698.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946997058.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946732015.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946842116.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946958777.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946792883.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946780280.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946971499.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946980260.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946779442.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946787122.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946874637.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946965979.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946792521.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946970535.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946942217.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946871516.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946741016.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946820693.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946857477.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946782924.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946804886.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946967656.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946897559.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946784361.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946755680.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946793483.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946939216.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946752678.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946838694.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946990460.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946955776.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946835693.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946990821.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946842715.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946923612.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946878837.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946858196.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946875000.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946789043.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946829813.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946919653.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946918933.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946965497.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946822013.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946813731.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946941013.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946888440.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946974979.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946852194.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946859396.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946956376.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946964895.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946936093.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946927575.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946945097.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946987459.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946921933.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946891560.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946971616.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946921573.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946731893.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946956615.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946981338.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946952413.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946845353.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946868635.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946965256.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946773563.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946897321.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946824054.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946862278.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946734655.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946930570.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946754120.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946932976.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946830653.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946996822.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946845472.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946811692.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946962018.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946793361.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946872115.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946771642.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946872476.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946826334.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946739335.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946854354.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946986017.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946797805.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946854717.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946774400.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946988061.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946882917.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946735976.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946883159.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946936213.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946818292.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946812294.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946847155.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946995017.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946939695.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946920851.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946756998.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946864195.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946776683.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946807043.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946990698.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946793004.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946772480.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946830173.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946975219.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946829212.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946932736.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946829933.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946969337.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946976898.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946732971.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946858916.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946849915.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946969458.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946767559.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946798166.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data947002316.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946823213.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946948574.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946803444.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946953615.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946925053.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946967535.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946827655.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946741133.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946811571.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946813853.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946853033.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946736455.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946796484.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946969575.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946989021.csv
# Reading current file:
# ...
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946820334.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946772364.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946858796.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946814090.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946919175.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946852794.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946804766.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946964178.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946788561.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946850876.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946990099.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946828373.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946894560.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946957576.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946777644.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946733212.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946871399.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946957335.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946794564.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946824775.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946950856.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946999582.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946869476.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946776200.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946964055.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946978338.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946753881.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946781723.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946994419.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946968019.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946856637.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946771284.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946826091.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946928293.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946959377.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946999338.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946854954.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946818054.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946998500.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946737653.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946971020.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946876079.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946734176.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946793721.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946954577.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946787361.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946984817.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946871876.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946972100.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946808936.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946993579.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946981819.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946829096.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946935373.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946852317.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946882079.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946878116.csv
# Reading current file:
# /home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946875355.csv
#
# #####################################################
# !!! DONE READING & MERGING DATA !!!
# #####################################################
#
# ------------------------------------------------------
# All files: 2051
#
# Successfully appended files: 2037
# ------------------------------------------------------
# ------------------------------------------------------
#
# Empty files without headers: 0
# []
#
# Zero size files: 1
# ['/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946684854.csv']
#
# Empty row files: 13
# ['/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946748163.csv', '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data947002770.csv', '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data947016116.csv', '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946897798.csv', '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946684858.csv', '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946685926.csv', '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946685134.csv', '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946684866.csv', '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946808127.csv', '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data947016237.csv', '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data947001498.csv', '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946741855.csv', '/home/taco/Documents/greta_forarex/Neue gesammelten Daten für Timmy_08082019/Flight Experiment_Postflight_raw_20190808/Postflightdata direkt nach Recovery_11032019 bis 14032019/data946685774.csv']
#
# #####################################################

# %%
#  READING IN DATA
#pre_and_flight = pd.read_pickle('../data/experiment/merged/pre_and_flight_merged.pkl')
postflight_1 = pd.read_pickle('../data/experiment/merged/postflight_1_merged.pkl')
postflight_2 = pd.read_pickle('../data/experiment/merged/postflight_2_merged.pkl')

# %%
# Saving to disk the merged files (not yet processed)
# In Pickle format for fast read in
#pre_and_flight.to_pickle('../data/experiment/merged/pre_and_flight_merged.pkl')
postflight_2.to_pickle('../data/experiment/merged/postflight_1_merged.pkl')
#extra.to_pickle('../data/experiment/merged/extra_merged.pkl')
# In CSV
#pre_and_flight.to_csv('../data/experiment/merged/pre_and_flight_merged.csv')
postflight_2.to_csv('../data/experiment/merged/postflight_1_merged.csv')
#extra.to_csv('../data/experiment/merged/extra_merged.csv')

# %%
## Remove all unncessary columns
cols_to_keep = ['timeStamp',
                'Exp0_OxygenTemp', 'Exp0_OxygenpercentO2', 'Exp0_PhValue',
                'Exp1_OxygenTemp', 'Exp1_OxygenpercentO2',
                'Pressure_LateAccess']

#pre_and_flight = pre_and_flight[cols_to_keep]
postflight_2 = postflight_1[cols_to_keep]
#extra = extra[cols_to_keep]

# %%
# DFs contain negligible amount of missing values (NAs), just drop them
#import missingno as msno
#msno.matrix(postflight_1)
#pre_and_flight.dropna(inplace=True)
postflight_2.dropna(inplace=True)
#extra.dropna(inplace=True)

# %%
# Naive DateTime TimeStamp needs to be increased by 1hour (UTC+1 for Sweden) compared to what was recorded (apparently UTC, UK)
#pre_and_flight.loc[:,'timeStamp'] = pd.to_datetime(pre_and_flight.timeStamp, unit='s')
postflight_2.loc[:,'timeStamp'] = pd.to_datetime(postflight_2.timeStamp, unit='s')
#extra.loc[:,'timeStamp'] = pd.to_datetime(extra.timeStamp, unit='s').dt.tz_localize('UTC').dt.tz_convert('Europe/Stockholm')

# %%
# Check the data range of the final timestamps
#pre_and_flight.timeStamp.min()
#pre_and_flight.timeStamp.max()
postflight_1.timeStamp.min()
postflight_1.timeStamp.max()
postflight_2.timeStamp.min()
postflight_2.timeStamp.max()

#extra.timeStamp.min()
#extra.timeStamp.max()
# Out:
# Timestamp('2000-01-01 00:02:46')
# Timestamp('2000-01-04 20:03:51')
# Timestamp('2000-01-01 00:02:46')
# Timestamp('2000-01-04 20:03:51')

# %%
postflight_1.head()
postflight_2.head()
# Out:
#             timeStamp  Exp0_OxygenTemp  Exp0_OxygenpercentO2  Exp0_PhValue  Exp1_OxygenTemp  Exp1_OxygenpercentO2  Pressure_LateAccess  year  month  day  hour  minute  second
# 0 2000-01-01 21:29:17            29277                  9907          7111            31550                    27                 9657  2000      1    1    21      29      17
# 1 2000-01-01 21:29:24            29275                  9988          7110            31548                    27                 9659  2000      1    1    21      29      24
# 2 2000-01-01 21:29:30            29277                  9789          7111            31545                    37                 9658  2000      1    1    21      29      30
# 3 2000-01-01 21:29:36            29272                  9804          7111            31542                    20                 9659  2000      1    1    21      29      36
# 4 2000-01-01 21:29:42            29277                  9867          7112            31550            4294967267                 9657  2000      1    1    21      29      42
#             timeStamp  Exp0_OxygenTemp  Exp0_OxygenpercentO2  Exp0_PhValue  Exp1_OxygenTemp  Exp1_OxygenpercentO2  Pressure_LateAccess
# 0 2000-01-01 21:29:17            29277                  9907          7111            31550                    27                 9657
# 1 2000-01-01 21:29:24            29275                  9988          7110            31548                    27                 9659
# 2 2000-01-01 21:29:30            29277                  9789          7111            31545                    37                 9658
# 3 2000-01-01 21:29:36            29272                  9804          7111            31542                    20                 9659
# 4 2000-01-01 21:29:42            29277                  9867          7112            31550            4294967267                 9657

# %%
# Create different time epochs for convenient plotting & exploration
# Pre and Flight
#pre_and_flight.loc[:, 'year'] = pre_and_flight.timeStamp.dt.year
#pre_and_flight.loc[:, 'month'] = pre_and_flight.timeStamp.dt.month
#pre_and_flight.loc[:, 'day'] = pre_and_flight.timeStamp.dt.day
#pre_and_flight.loc[:, 'hour'] = pre_and_flight.timeStamp.dt.hour
#pre_and_flight.loc[:, 'minute'] = pre_and_flight.timeStamp.dt.minute
#pre_and_flight.loc[:, 'second'] = pre_and_flight.timeStamp.dt.second

# Postflight
postflight_1.loc[:, 'year'] = postflight_1.timeStamp.dt.year
postflight_1.loc[:, 'month'] = postflight_1.timeStamp.dt.month
postflight_1.loc[:, 'day'] = postflight_1.timeStamp.dt.day
postflight_1.loc[:, 'hour'] = postflight_1.timeStamp.dt.hour
postflight_1.loc[:, 'minute'] = postflight_1.timeStamp.dt.minute
postflight_1.loc[:, 'second'] = postflight_1.timeStamp.dt.second

# Extra
#extra.loc[:, 'year'] = extra.timeStamp.dt.year
#extra.loc[:, 'month'] = extra.timeStamp.dt.month
#extra.loc[:, 'day'] = extra.timeStamp.dt.day
#extra.loc[:, 'hour'] = extra.timeStamp.dt.hour
#extra.loc[:, 'minute'] = extra.timeStamp.dt.minute
#extra.loc[:, 'second'] = extra.timeStamp.dt.second

# %%
#Wichtige Zeitpunkte:
#- Ende Late Access (LA) 11.03.2019  07:45:58
end_late_access = pd.to_datetime('2019-03-11 07:45:58').tz_localize('Europe/Stockholm')#.tz_convert('Europe/Stockholm')
#- Lift-Off (LO) 11.03.2019  10:19:56  --- 11.03.2019 10:20:00 1552296000 Lift-Off (LO)
lift_off = pd.to_datetime('2019-03-11 10:20:00').tz_localize('Europe/Stockholm')#.tz_convert('Europe/Stockholm')
#- De-Spin (keine Rotierung der Rakete) ~ Nullbewegung in alle Richtungen im Video nach 1 min 7s 38 ms nach LO
de_spin = lift_off + pd.Timedelta('1 minutes 7 seconds')
#- Ende des Raketenantriebs (Motorabwurf, keine Beschleunigung, keine Hypergravitation) 1 min 10 s 20 ms nach LO
end_rocket_propulsion = lift_off + pd.Timedelta('1 minutes 10 seconds')
#- Apogee (Zeitpunkt zu dem die Rakete den höchsten Höhenmeter erreicht hat) 124,4 Sekunden nach LO (errreichte Höhe 82,184 km)
apogee = lift_off + pd.Timedelta('124 seconds')
#- Auswurf 1. Fallschirm ~ 5 min 55 s nach LO
parachute_1 = lift_off + pd.Timedelta('5 minutes 55 seconds')
#- Auswurf 2. Fallschirm ~ 6 min 20 s nach LO
parachute_2 = lift_off + pd.Timedelta('6 minutes 20 seconds')
#- Zeitpunkt der Landung 11.03.2019 10:33:41.800000
landing = pd.to_datetime('2019-03-11 10:33:41').tz_localize('Europe/Stockholm')

# %%
# Sort DF by timeStamp
pre_and_flight.sort_values(by='timeStamp', axis=0, ascending=True, inplace=True)
postflight.sort_values(by='timeStamp', axis=0, ascending=True, inplace=True)
#extra.sort_values(by='timeStamp', axis=0, ascending=True, inplace=True)
# Make timestamp index of DF for easier plotting
#pre_and_flight.set_index('timeStamp', inplace=True)
#postflight.set_index('timeStamp', inplace=True)

# %%
# Scale columns values 

# Pre-and flight
pre_and_flight.loc[:,'Exp0_OxygenTemp'] = pre_and_flight.Exp0_OxygenTemp/1000
pre_and_flight.loc[:,'Exp1_OxygenTemp'] = pre_and_flight.Exp1_OxygenTemp/1000
pre_and_flight.loc[:,'Exp0_OxygenpercentO2'] = pre_and_flight.Exp0_OxygenpercentO2/1000
pre_and_flight.loc[:,'Exp1_OxygenpercentO2'] = pre_and_flight.Exp1_OxygenpercentO2/1000

# Postflight
postflight.loc[:,'Exp0_OxygenTemp'] = postflight.Exp0_OxygenTemp/1000
postflight.loc[:,'Exp1_OxygenTemp'] = postflight.Exp1_OxygenTemp/1000
postflight.loc[:,'Exp0_OxygenpercentO2'] = postflight.Exp0_OxygenpercentO2/1000
postflight.loc[:,'Exp1_OxygenpercentO2'] = postflight.Exp1_OxygenpercentO2/1000

# %%
# Saving to disk
# In Pickle format for fast read in
#pre_and_flight.to_pickle('../data/experiment/processed/pre_and_flight_merged.pkl')
#postflight.to_pickle('../data/experiment/processed//postflight_merged.pkl')

# In CSV
#pre_and_flight.to_csv('../data/experiment/processed//pre_and_flight_merged.csv')
#postflight.to_csv('../data/experiment/processed//postflight_merged.csv')

# %%
# Pandas Profiling conveniently returns an extensive report with descriptive statistics for each DF
#pre_and_flight.profile_report(style={'full_width':True})
#postflight.profile_report(style={'full_width':True})

# %%
# Explore which year, days, hours and minutes were actually recorded
#plt.figure(figsize=(18, 6))
#pre_and_flight.set_index('timeStamp', inplace=True)

# %%
import matplotlib.pyplot as plt
from matplotlib import dates
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(22, 8)})
flight_start = pd.to_datetime('2019-03-11 10:01').tz_localize('Europe/Stockholm')
#pre_and_flight[pre_and_flight.index >= flight_start].sort_values('timeStamp').Exp0_OxygenTemp.plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9))
sns.lineplot(
            x = pre_and_flight[pre_and_flight.timeStamp > flight_start].timeStamp,
            y = pre_and_flight[pre_and_flight.timeStamp > flight_start].Exp0_OxygenTemp
            )

events_list = [flight_start, lift_off, de_spin, end_rocket_propulsion, apogee, parachute_1, parachute_2, landing]
for event in events_list:
    plt.axvline(x=event, color='r')
   
#plt.axvline(x=flight_start, color = 'black')
#plt.axvline(x=lift_off, color = 'blue')
#plt.axvline(x=de_spin, color = 'red')
#plt.axvline(x=end_rocket_propulsion, color = 'r')
#plt.axvline(x=apogee, color = 'r')
#plt.axvline(x=parachute_1, color = 'grey')
#plt.axvline(x=parachute_2, color = 'grey')
#plt.axvline(x=landing, color = 'black')
plt.text(flight_start, 34, 'Flight Start', horizontalalignment='left', size='small', color='black')
plt.text(lift_off, 34.1, 'Lift-Off', horizontalalignment='left', size='small', color='black')
plt.text(de_spin, 33.2, 'De Spin', horizontalalignment='left', size='small', color='black')
plt.text(end_rocket_propulsion, 32, 'End Rocket Propulsion', horizontalalignment='left', size='small', color='black')
plt.text(apogee, 31, 'Apogee', horizontalalignment='left', size='small', color='black')
plt.text(parachute_1, 32.5, 'Parachute 1', horizontalalignment='left', size='small', color='black')
plt.text(parachute_2, 32.2, 'Parachute 2', horizontalalignment='left', size='small', color='black')
plt.text(landing, 32, 'Landing', horizontalalignment='left', size='small', color='black')


# get current axis
#ax = plt.gca()
# get current xtick labels
ax.fmt_xdata = dates.DateFormatter('%H:%M:%S')
# convert all xtick labels to selected format from ms timestamp
#ax.set_xticklabels(pre_and_flight[pre_and_flight.timeStamp > flight_start].timeStamp.dt.strftime('%H:%M:%S') ,
# rotation=50)

plt.show()
# Out:
# /home/taco/anaconda3/lib/python3.6/site-packages/seaborn/relational.py:792: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   x, y = np.asarray(x), np.asarray(y)
# /home/taco/anaconda3/lib/python3.6/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5a0a48811b4a> in <module>
#      36 #ax = plt.gca()
#      37 # get current xtick labels
# ---> 38 ax.fmt_xdata = dates.DateFormatter('%H:%M:%S')
#      39 # convert all xtick labels to selected format from ms timestamp
#      40 #ax.set_xticklabels(pre_and_flight[pre_and_flight.timeStamp > flight_start].timeStamp.dt.strftime('%H:%M:%S') ,
#
# NameError: name 'ax' is not defined

# %%
import matplotlib.pyplot as plt
from matplotlib import dates
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(22, 8)})
flight_start = pd.to_datetime('2019-03-11 10:01').tz_localize('Europe/Stockholm')
#pre_and_flight[pre_and_flight.index >= flight_start].sort_values('timeStamp').Exp0_OxygenTemp.plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9))
sns.lineplot(
            x = pre_and_flight[pre_and_flight.timeStamp >= lift_off].timeStamp,
            y = pre_and_flight[pre_and_flight.timeStamp >= lift_off].Exp0_OxygenTemp
            )

events_list = [lift_off, de_spin, end_rocket_propulsion, apogee, parachute_1, parachute_2, landing]
for event in events_list:
    plt.axvline(x=event, color='r')
   
#plt.axvline(x=flight_start, color = 'black')
#plt.axvline(x=lift_off, color = 'blue')
#plt.axvline(x=de_spin, color = 'red')
#plt.axvline(x=end_rocket_propulsion, color = 'r')
#plt.axvline(x=apogee, color = 'r')
#plt.axvline(x=parachute_1, color = 'grey')
#plt.axvline(x=parachute_2, color = 'grey')
#plt.axvline(x=landing, color = 'black')

plt.text(lift_off, 33.1, 'Lift-Off', horizontalalignment='left', size='small', color='black')
plt.text(de_spin, 33.2, 'De Spin', horizontalalignment='left', size='small', color='black')
plt.text(end_rocket_propulsion, 33.6, 'End Rocket Propulsion', horizontalalignment='left', size='small', color='black')
plt.text(apogee, 33, 'Apogee', horizontalalignment='left', size='small', color='black')
plt.text(parachute_1, 33.1, 'Parachute 1', horizontalalignment='left', size='small', color='black')
plt.text(parachute_2, 33.4, 'Parachute 2', horizontalalignment='left', size='small', color='black')
plt.text(landing, 33.1, 'Landing', horizontalalignment='left', size='small', color='black')


# get current axis
#ax = plt.gca()
# get current xtick labels
#ax.fmt_xdata = dates.DateFormatter('%H:%M:%S')
# convert all xtick labels to selected format from ms timestamp
#ax.set_xticklabels(pre_and_flight[pre_and_flight.timeStamp > flight_start].timeStamp.dt.strftime('%H:%M:%S') ,
# rotation=50)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import dates
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(22, 8)})
flight_start = pd.to_datetime('2019-03-11 10:01').tz_localize('Europe/Stockholm')
#pre_and_flight[pre_and_flight.index >= flight_start].sort_values('timeStamp').Exp0_OxygenTemp.plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9))
sns.lineplot(
            x = pre_and_flight[pre_and_flight.timeStamp > flight_start].timeStamp,
            y = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[1]]
            )

events_list = [flight_start, lift_off, de_spin, end_rocket_propulsion, apogee, parachute_1, parachute_2, landing]
for event in events_list:
    plt.axvline(x=event, color='r')
ylimits = ax.get_ylim()
import random
#plt.axvline(x=flight_start, color = 'black')
#plt.axvline(x=lift_off, color = 'blue')
#plt.axvline(x=de_spin, color = 'red')
#plt.axvline(x=end_rocket_propulsion, color = 'r')
#plt.axvline(x=apogee, color = 'r')
#plt.axvline(x=parachute_1, color = 'grey')
#plt.axvline(x=parachute_2, color = 'grey')
#plt.axvline(x=landing, color = 'black')
plt.text(flight_start, random.uniform(ylimits[0],ylimits[1]), 'Flight Start', horizontalalignment='left', size='small', color='black')
plt.text(lift_off, random.uniform(ylimits[0],ylimits[1]), 'Lift-Off', horizontalalignment='left', size='small', color='black')
plt.text(de_spin, random.uniform(ylimits[0],ylimits[1]), 'De Spin', horizontalalignment='left', size='small', color='black')
plt.text(end_rocket_propulsion, random.uniform(ylimits[0],ylimits[1]), 'End Rocket Propulsion', horizontalalignment='left', size='small', color='black')
plt.text(apogee, random.uniform(ylimits[0],ylimits[1]), 'Apogee', horizontalalignment='left', size='small', color='black')
plt.text(parachute_1, random.uniform(ylimits[0],ylimits[1]), 'Parachute 1', horizontalalignment='left', size='small', color='black')
plt.text(parachute_2, random.uniform(ylimits[0],ylimits[1]), 'Parachute 2', horizontalalignment='left', size='small', color='black')
plt.text(landing, random.uniform(ylimits[0],ylimits[1]), 'Landing', horizontalalignment='left', size='small', color='black')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-5cc9506d48da> in <module>
#      14 for event in events_list:
#      15     plt.axvline(x=event, color='r')
# ---> 16 ylimits = ax.get_ylim()
#      17 import random
#      18 #plt.axvline(x=flight_start, color = 'black')
#
# NameError: name 'ax' is not defined

# %%
import matplotlib.pyplot as plt
from matplotlib import dates
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(22, 8)})
flight_start = pd.to_datetime('2019-03-11 10:01').tz_localize('Europe/Stockholm')
#pre_and_flight[pre_and_flight.index >= flight_start].sort_values('timeStamp').Exp0_OxygenTemp.plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9))
ax = sns.lineplot(
            x = pre_and_flight[pre_and_flight.timeStamp > flight_start].timeStamp,
            y = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[1]]
            )

y_min = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[1]].min()
y_max = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[1]].max()

events_list = [flight_start, lift_off, de_spin, end_rocket_propulsion, apogee, parachute_1, parachute_2, landing]
for event in events_list:
    plt.axvline(x=event, color='r')
#plt.axvline(x=flight_start, color = 'black')
#plt.axvline(x=lift_off, color = 'blue')
#plt.axvline(x=de_spin, color = 'red')
#plt.axvline(x=end_rocket_propulsion, color = 'r')
#plt.axvline(x=apogee, color = 'r')
#plt.axvline(x=parachute_1, color = 'grey')
#plt.axvline(x=parachute_2, color = 'grey')
#plt.axvline(x=landing, color = 'black')
plt.text(flight_start, random.uniform(y_min,y_max), 'Flight Start', horizontalalignment='left', size='small', color='black')
plt.text(lift_off, random.uniform(y_min,y_max), 'Lift-Off', horizontalalignment='left', size='small', color='black')
plt.text(de_spin, random.uniform(y_min,y_max), 'De Spin', horizontalalignment='left', size='small', color='black')
plt.text(end_rocket_propulsion, random.uniform(y_min,y_max), 'End Rocket Propulsion', horizontalalignment='left', size='small', color='black')
plt.text(apogee, random.uniform(y_min,y_max), 'Apogee', horizontalalignment='left', size='small', color='black')
plt.text(parachute_1, random.uniform(y_min,y_max), 'Parachute 1', horizontalalignment='left', size='small', color='black')
plt.text(parachute_2, random.uniform(y_min,y_max), 'Parachute 2', horizontalalignment='left', size='small', color='black')
plt.text(landing, random.uniform(y_min,y_max), 'Landing', horizontalalignment='left', size='small', color='black')

from matplotlib.ticker import AutoMinorLocator, AutoLocator
from matplotlib.dates import DateFormatter
#ax.xaxis.set_major_locator()
#ax.xaxis.set_minor_locator(AutoMinorLocator())
myFmt = DateFormatter("%H/%M") 
ax.xaxis.set_major_formatter(myFmt) 
 

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import dates
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(22, 8)})
flight_start = pd.to_datetime('2019-03-11 10:01').tz_localize('Europe/Stockholm')
#pre_and_flight[pre_and_flight.index >= flight_start].sort_values('timeStamp').Exp0_OxygenTemp.plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9))
sns.lineplot(
            x = pre_and_flight[pre_and_flight.timeStamp > flight_start].timeStamp,
            y = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[2]]
            )

y_min = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[2]].min()
y_max = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[2]].max()

events_list = [flight_start, lift_off, de_spin, end_rocket_propulsion, apogee, parachute_1, parachute_2, landing]
for event in events_list:
    plt.axvline(x=event, color='r')
#plt.axvline(x=flight_start, color = 'black')
#plt.axvline(x=lift_off, color = 'blue')
#plt.axvline(x=de_spin, color = 'red')
#plt.axvline(x=end_rocket_propulsion, color = 'r')
#plt.axvline(x=apogee, color = 'r')
#plt.axvline(x=parachute_1, color = 'grey')
#plt.axvline(x=parachute_2, color = 'grey')
#plt.axvline(x=landing, color = 'black')
plt.text(flight_start, random.uniform(y_min,y_max), 'Flight Start', horizontalalignment='left', size='small', color='black')
plt.text(lift_off, random.uniform(y_min,y_max), 'Lift-Off', horizontalalignment='left', size='small', color='black')
plt.text(de_spin, random.uniform(y_min,y_max), 'De Spin', horizontalalignment='left', size='small', color='black')
plt.text(end_rocket_propulsion, random.uniform(y_min,y_max), 'End Rocket Propulsion', horizontalalignment='left', size='small', color='black')
plt.text(apogee, random.uniform(y_min,y_max), 'Apogee', horizontalalignment='left', size='small', color='black')
plt.text(parachute_1, random.uniform(y_min,y_max), 'Parachute 1', horizontalalignment='left', size='small', color='black')
plt.text(parachute_2, random.uniform(y_min,y_max), 'Parachute 2', horizontalalignment='left', size='small', color='black')
plt.text(landing, random.uniform(y_min,y_max), 'Landing', horizontalalignment='left', size='small', color='black')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import dates
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(22, 8)})
flight_start = pd.to_datetime('2019-03-11 10:01').tz_localize('Europe/Stockholm')
#pre_and_flight[pre_and_flight.index >= flight_start].sort_values('timeStamp').Exp0_OxygenTemp.plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9))
sns.lineplot(
            x = pre_and_flight[pre_and_flight.timeStamp > flight_start].timeStamp,
            y = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[3]]
            )

y_min = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[3]].min()
y_max = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[3]].max()

events_list = [flight_start, lift_off, de_spin, end_rocket_propulsion, apogee, parachute_1, parachute_2, landing]
for event in events_list:
    plt.axvline(x=event, color='r')
#plt.axvline(x=flight_start, color = 'black')
#plt.axvline(x=lift_off, color = 'blue')
#plt.axvline(x=de_spin, color = 'red')
#plt.axvline(x=end_rocket_propulsion, color = 'r')
#plt.axvline(x=apogee, color = 'r')
#plt.axvline(x=parachute_1, color = 'grey')
#plt.axvline(x=parachute_2, color = 'grey')
#plt.axvline(x=landing, color = 'black')
plt.text(flight_start, random.uniform(y_min,y_max), 'Flight Start', horizontalalignment='left', size='small', color='black')
plt.text(lift_off, random.uniform(y_min,y_max), 'Lift-Off', horizontalalignment='left', size='small', color='black')
plt.text(de_spin, random.uniform(y_min,y_max), 'De Spin', horizontalalignment='left', size='small', color='black')
plt.text(end_rocket_propulsion, random.uniform(y_min,y_max), 'End Rocket Propulsion', horizontalalignment='left', size='small', color='black')
plt.text(apogee, random.uniform(y_min,y_max), 'Apogee', horizontalalignment='left', size='small', color='black')
plt.text(parachute_1, random.uniform(y_min,y_max), 'Parachute 1', horizontalalignment='left', size='small', color='black')
plt.text(parachute_2, random.uniform(y_min,y_max), 'Parachute 2', horizontalalignment='left', size='small', color='black')
plt.text(landing, random.uniform(y_min,y_max), 'Landing', horizontalalignment='left', size='small', color='black')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import dates
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(22, 8)})
flight_start = pd.to_datetime('2019-03-11 10:01').tz_localize('Europe/Stockholm')
#pre_and_flight[pre_and_flight.index >= flight_start].sort_values('timeStamp').Exp0_OxygenTemp.plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9))
sns.lineplot(
            x = pre_and_flight[pre_and_flight.timeStamp > flight_start].timeStamp,
            y = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[4]]
            )

y_min = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[4]].min()
y_max = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[4]].max()

events_list = [flight_start, lift_off, de_spin, end_rocket_propulsion, apogee, parachute_1, parachute_2, landing]
for event in events_list:
    plt.axvline(x=event, color='r')
#plt.axvline(x=flight_start, color = 'black')
#plt.axvline(x=lift_off, color = 'blue')
#plt.axvline(x=de_spin, color = 'red')
#plt.axvline(x=end_rocket_propulsion, color = 'r')
#plt.axvline(x=apogee, color = 'r')
#plt.axvline(x=parachute_1, color = 'grey')
#plt.axvline(x=parachute_2, color = 'grey')
#plt.axvline(x=landing, color = 'black')
plt.text(flight_start, random.uniform(y_min,y_max), 'Flight Start', horizontalalignment='left', size='small', color='black')
plt.text(lift_off, random.uniform(y_min,y_max), 'Lift-Off', horizontalalignment='left', size='small', color='black')
plt.text(de_spin, random.uniform(y_min,y_max), 'De Spin', horizontalalignment='left', size='small', color='black')
plt.text(end_rocket_propulsion, random.uniform(y_min,y_max), 'End Rocket Propulsion', horizontalalignment='left', size='small', color='black')
plt.text(apogee, random.uniform(y_min,y_max), 'Apogee', horizontalalignment='left', size='small', color='black')
plt.text(parachute_1, random.uniform(y_min,y_max), 'Parachute 1', horizontalalignment='left', size='small', color='black')
plt.text(parachute_2, random.uniform(y_min,y_max), 'Parachute 2', horizontalalignment='left', size='small', color='black')
plt.text(landing, random.uniform(y_min,y_max), 'Landing', horizontalalignment='left', size='small', color='black')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import dates
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(22, 8)})
flight_start = pd.to_datetime('2019-03-11 10:01').tz_localize('Europe/Stockholm')
#pre_and_flight[pre_and_flight.index >= flight_start].sort_values('timeStamp').Exp0_OxygenTemp.plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9))
sns.lineplot(
            x = pre_and_flight[pre_and_flight.timeStamp > flight_start].timeStamp,
            y = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[5]]
            )

y_min = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[5]].min()
y_max = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[5]].max()

events_list = [flight_start, lift_off, de_spin, end_rocket_propulsion, apogee, parachute_1, parachute_2, landing]
for event in events_list:
    plt.axvline(x=event, color='r')
#plt.axvline(x=flight_start, color = 'black')
#plt.axvline(x=lift_off, color = 'blue')
#plt.axvline(x=de_spin, color = 'red')
#plt.axvline(x=end_rocket_propulsion, color = 'r')
#plt.axvline(x=apogee, color = 'r')
#plt.axvline(x=parachute_1, color = 'grey')
#plt.axvline(x=parachute_2, color = 'grey')
#plt.axvline(x=landing, color = 'black')
plt.text(flight_start, random.uniform(y_min,y_max), 'Flight Start', horizontalalignment='left', size='small', color='black')
plt.text(lift_off, random.uniform(y_min,y_max), 'Lift-Off', horizontalalignment='left', size='small', color='black')
plt.text(de_spin, random.uniform(y_min,y_max), 'De Spin', horizontalalignment='left', size='small', color='black')
plt.text(end_rocket_propulsion, random.uniform(y_min,y_max), 'End Rocket Propulsion', horizontalalignment='left', size='small', color='black')
plt.text(apogee, random.uniform(y_min,y_max), 'Apogee', horizontalalignment='left', size='small', color='black')
plt.text(parachute_1, random.uniform(y_min,y_max), 'Parachute 1', horizontalalignment='left', size='small', color='black')
plt.text(parachute_2, random.uniform(y_min,y_max), 'Parachute 2', horizontalalignment='left', size='small', color='black')
plt.text(landing, random.uniform(y_min,y_max), 'Landing', horizontalalignment='left', size='small', color='black')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import dates
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(22, 8)})
flight_start = pd.to_datetime('2019-03-11 10:01').tz_localize('Europe/Stockholm')
#pre_and_flight[pre_and_flight.index >= flight_start].sort_values('timeStamp').Exp0_OxygenTemp.plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9))
sns.lineplot(
            x = pre_and_flight[pre_and_flight.timeStamp > flight_start].timeStamp,
            y = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[6]]
            )

y_min = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[6]].min()
y_max = pre_and_flight[pre_and_flight.timeStamp > flight_start][cols_to_keep[6]].max()

events_list = [flight_start, lift_off, de_spin, end_rocket_propulsion, apogee, parachute_1, parachute_2, landing]
for event in events_list:
    plt.axvline(x=event, color='r')
#plt.axvline(x=flight_start, color = 'black')
#plt.axvline(x=lift_off, color = 'blue')
#plt.axvline(x=de_spin, color = 'red')
#plt.axvline(x=end_rocket_propulsion, color = 'r')
#plt.axvline(x=apogee, color = 'r')
#plt.axvline(x=parachute_1, color = 'grey')
#plt.axvline(x=parachute_2, color = 'grey')
#plt.axvline(x=landing, color = 'black')
plt.text(flight_start, random.uniform(y_min,y_max), 'Flight Start', horizontalalignment='left', size='small', color='black')
plt.text(lift_off, random.uniform(y_min,y_max), 'Lift-Off', horizontalalignment='left', size='small', color='black')
plt.text(de_spin, random.uniform(y_min,y_max), 'De Spin', horizontalalignment='left', size='small', color='black')
plt.text(end_rocket_propulsion, random.uniform(y_min,y_max), 'End Rocket Propulsion', horizontalalignment='left', size='small', color='black')
plt.text(apogee, random.uniform(y_min,y_max), 'Apogee', horizontalalignment='left', size='small', color='black')
plt.text(parachute_1, random.uniform(y_min,y_max), 'Parachute 1', horizontalalignment='left', size='small', color='black')
plt.text(parachute_2, random.uniform(y_min,y_max), 'Parachute 2', horizontalalignment='left', size='small', color='black')
plt.text(landing, random.uniform(y_min,y_max), 'Landing', horizontalalignment='left', size='small', color='black')

plt.show()
