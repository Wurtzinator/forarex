# %%
#############################################################################
####################Import all packages######################################
#############################################################################
import os
import numpy as np
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.options.mode.chained_assignment = None  # default='warn'
# Set working directory
os.chdir('/home/taco/Documents/greta_forarex/data')
os.getcwd()
#############################################################################
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# '/home/taco/Documents/greta_forarex/data'

# %%
df_exp_merg = pd.read_csv('experiment/merged/exp_merged_pre_and_flight.csv')
df_ctrl_merg = pd.read_csv('control/merged/control_merged_raw.csv')
df_exp_merg.head()
df_ctrl_merg.head()
# Out:
#     timeStamp  Exp0_OxygenTemp  Exp0_Oxygendphi  Exp0_OxygenpercentO2  Exp0_OxygensingelIntensity  Exp0_OxygenAmbientLight  Exp0_PhValue  Exp0_PresensO2value  Exp0_PH.calTemp  Exp0_PH.Ref.Amplitude  Exp0_PH.Amplitude  Exp0_PH.Phase.shift  Exp0_PH.calibration.Pressure  Exp0_Presens.02.Ref.Amp  Exp0_Presens.02.Amp  Exp0_Presens.02.Phase  Exp0_Presens.02.cal.Temp  Exp0_Presens.errorcode  Exp0_TempPump  Exp0_TempCamera  Exp1_OxygenTemp  Exp1_Oxygendphi  Exp1_OxygenpercentO2  Exp1_OxygensingelIntensity  Exp1_OxygenAmbientLight  Exp1_PhValue  Exp1_PresensO2value  Exp1_PH.calTemp  Exp1_PH.Ref.Amplitude  Exp1_PH.Amplitude  Exp1_PH.Phase.shift  Exp1_PH.calibration.Pressure  Exp1_Presens.02.Ref.Amp  Exp1_Presens.02.Amp  Exp1_Presens.02.Phase  Exp1_Presens.02.cal.Temp  Exp1_Presens.errorcode  Exp1_TempPump  Exp1_TempCamera  Temp_airHighPresision  Temp_Heater  Pressure_Electronics  Pressure_LateAccess  Imu_gyroX  Imu_gyroY  Imu_gyroZ  Imu_accelegrationX  Imu_accelegrationY  Imu_accelegrationZ  \
# ...

# %%
cols_to_keep = ['timeStamp',
                'Exp0_OxygenTemp', 'Exp0_OxygenpercentO2', 'Exp0_PhValue',
                'Exp1_OxygenTemp', 'Exp1_OxygenpercentO2',
                'Pressure_LateAccess']
df_ctrl = df_ctrl_merg[cols_to_keep]
df_exp = df_exp_merg[cols_to_keep]
df_ctrl.head()
df_exp.head()
# Out:
#     timeStamp  Exp0_OxygenTemp  Exp0_OxygenpercentO2  Exp0_PhValue  Exp1_OxygenTemp  Exp1_OxygenpercentO2  Pressure_LateAccess
# 0  1556623079                0                     0             0                0                     0                65535
# 1  1556623081                0                     0             0                0                     0                65535
# 2  1556623083                0                     0             0                0                     0                65535
# 3  1556623085                0                     0             0                0                     0                65535
# 4  1556623087                0                     0             0                0                     0                65535
#     timeStamp  Exp0_OxygenTemp  Exp0_OxygenpercentO2  Exp0_PhValue  Exp1_OxygenTemp  Exp1_OxygenpercentO2  Pressure_LateAccess
# ...

# %%
# Transform columns values
# Control
df_ctrl.loc['Exp0_OxygenTemp'] = df_ctrl.Exp0_OxygenTemp/1000
df_ctrl.loc['Exp1_OxygenTemp'] = df_ctrl.Exp1_OxygenTemp/1000
df_ctrl.loc['Exp0_OxygenpercentO2'] = df_ctrl.Exp0_OxygenpercentO2/1000
df_ctrl.loc['Exp1_OxygenpercentO2'] = df_ctrl.Exp1_OxygenpercentO2/1000
df_ctrl.loc['timeStamp'] = pd.to_datetime(df_ctrl.timeStamp, unit='s')
# Experiment
df_exp.loc['Exp0_OxygenTemp'] = df_exp.Exp0_OxygenTemp/1000
df_exp.loc['Exp1_OxygenTemp'] = df_exp.Exp1_OxygenTemp/1000
df_exp.loc['Exp0_OxygenpercentO2'] = df_exp.Exp0_OxygenpercentO2/1000
df_exp.loc['Exp1_OxygenpercentO2'] = df_exp.Exp1_OxygenpercentO2/1000
df_exp.loc['timeStamp'] = pd.to_datetime(df_exp.timeStamp, unit='s')
